# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

data={
    "Hours_Studied":[1,2,3,4,5,2,6,7,8,3],
    "Previous_Score":[40,45,50,55,60,42,70,75,80,48],
    "Results":["Fail","Fail","Fail","Pass","Pass","Fail","Pass","Pass","Pass","Fail"]
}

df=pd.DataFrame(data)
X=df[["Hours_Studied","Previous_Score"]].values
y=LabelEncoder().fit_transform(df["Results"])
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
model=Sequential()
model.add(Dense(4,input_dim=2,activation="relu"))
model.add(Dense(1,activation="sigmoid"))
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
model.fit(X_train,y_train,epochs=100,verbose=0)
loss,acc=model.evaluate(X_test,y_test,verbose=0)
print(f"\nTest Accuracy (Pass/Fail): {acc:.2f}")
y_pred=(model.predict(X_test)>=0.5).astype(int)
print("\nConfusion Matrix:")
print(confusion_matrix(y_test,y_pred))
print("\nClassification Report:")
print(classification_report(y_test,y_pred,target_names=["Fail","Pass"]))
new_student=np.array([[5,58]])
new_student_scaled=scaler.transform(new_student)
prob=model.predict(new_student_scaled)[0][0]
print(f"\nPredicted probability of PASS: {prob:.2f}")
print("Predicted label:","Pass" if prob>=0.5 else "Fail")
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Test Accuracy (Pass/Fail): 0.33
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
#
# Confusion Matrix:
# [[0 2]
#  [0 1]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Fail       0.00      0.00      0.00         2
#         Pass       0.33      1.00      0.50         1
#
#     accuracy                           0.33         3
#    macro avg       0.17      0.50      0.25         3
# weighted avg       0.11      0.33      0.17         3
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#
# Predicted probability of PASS: 0.68
# Predicted label: Pass
# ...
